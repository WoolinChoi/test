# %% [markdown]
# ### 나라별 데이타셋

# %%
# 데이타 읽어오기
import pandas
df = pandas.read_csv('./data/countries.tsv', sep='\t')  # 주의 /t은 안됨 - warning
df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
# 구조파악하기
print(type(df))
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.info())  # dtypes보다 구체적
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1704, 6)
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB
# None

# %% [markdown]
# [연습]

# %%
# !pip install chart-studio

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import matplotlib.pyplot as plt
import seaborn as sns
# import chart_studio.plotly as py

# %%
# 대륙별 국가 수 구하기
continent = df.continent.value_counts()
plt.figure(figsize=(10, 7))
sns.barplot(x=continent.index, y=continent.values)
plt.xticks(rotation=45)
plt.ylabel('Number of countries')
plt.xlabel('Continent')
plt.title('Number of Countries by Continent', color='red', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Number of Countries by Continent')

# %%
# 기대수명이 높은 국가 TOP 5
df.sort_values(by='lifeExp', ascending=False).country.iloc[0:5]
# Out:
# 803                Japan
# 671     Hong Kong, China
# 802                Japan
# 695              Iceland
# 1487         Switzerland
# Name: country, dtype: object

# %%
# 기대수명이 낮은 국가 TOP 5
df.sort_values(by='lifeExp', ascending=True).country.iloc[0:5]
# Out:
# 1292          Rwanda
# 0        Afghanistan
# 552           Gambia
# 36            Angola
# 1344    Sierra Leone
# Name: country, dtype: object

# %%
# 1 인당 GDP와 기대수명과의 관계
sns.lmplot(x='gdpPercap', y='lifeExp', data=df)

# %%
# 대륙별 GDP에 대한 박스 플롯 (아시아 대륙의 이상치(Outlier) 관측됨)
sns.boxplot(x='continent', y='gdpPercap', data=df, width=0.7, palette='Set3', fliersize=5)
plt.xticks(rotation=90)
plt.title('GDP BY continent', color='red')
# Out:
# Text(0.5, 1.0, 'GDP BY continent')

# %%
# 각 컬럼별 상관관계도
x = df.loc[:,['continent', 'country', 'year', 'gdpPercap', 'lifeExp']]
sns.pairplot(x, hue='continent', palette='deep')
