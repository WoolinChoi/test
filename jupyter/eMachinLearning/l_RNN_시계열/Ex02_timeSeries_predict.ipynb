# %%
import numpy as np
import matplotlib.pyplot as plt
import Ex02_timeSeries_data as t_d2
import Ex02_timeSeries_model as t_m2

(X_train2,Y_train2) = t_d2.make_data_Sequence2Sequence()
model2= t_m2.make_model()

# 학습 전 예측 결과
plt.subplot(211)
plt.plot([1, 2, 3], X_train2[1].flatten(), 'bo-', label="input sequence")
plt.plot([4, 5, 6], Y_train2[1].flatten(), 'ro-', label="target sequence")
plt.plot([4, 5, 6], model2.predict(X_train2[1:2,:,:]).flatten(), 'gs-', label="output sequence")
plt.xlim(-0.5, 7.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("Second sample sequence")

plt.subplot(212)
plt.plot([2, 3, 4], X_train2[2].flatten(), 'bo-', label="input sequence")
plt.plot([5, 6, 7], Y_train2[2].flatten(), 'ro-', label="target sequence")
plt.plot([5, 6, 7], model2.predict(X_train2[2:3,:,:]).flatten(), 'gs-', label="output sequence")
plt.xlim(-0.5, 7.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("Third sample sequence")
plt.tight_layout()
plt.show()

# 학습
history2 = model2.fit(X_train2, Y_train2, epochs=100, verbose=0)

# 학습 후 loss
plt.plot(history2.history["loss"])
plt.title("Loss")
plt.show()

# 학습 후 예측 결과
plt.subplot(211)
plt.plot([1, 2, 3], X_train2[1].flatten(), 'bo-', label="input sequence")
plt.plot([4, 5, 6], Y_train2[1].flatten(), 'ro-', label="target sequence")
plt.plot([4, 5, 6], model2.predict(X_train2[1:2,:,:]).flatten(), 'gs-', label="output sequence")
plt.xlim(-0.5, 7.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("Second sample sequence")


plt.subplot(212)
plt.plot([2, 3, 4], X_train2[2].flatten(), 'bo-', label="input sequence")
plt.plot([5, 6, 7], Y_train2[2].flatten(), 'ro-', label="target sequence")
plt.plot([5, 6, 7], model2.predict(X_train2[2:3,:,:]).flatten(), 'gs-', label="output sequence")
plt.xlim(-0.5, 7.5)
plt.ylim(-1.1, 1.1)
plt.legend()
plt.title("Third sample sequence")
plt.tight_layout()
plt.show()
# Out:
# X_train2.shape, Y_train2.shape  =  (16, 3, 1) (16, 3, 1)
# X_train2[0], Y_train2[0]  =  [[0.        ]
#  [0.70710678]
#  [1.        ]] [[ 7.07106781e-01]
#  [ 1.22464680e-16]
#  [-7.07106781e-01]]
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 3, 10)             120
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 3, 1)              11
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
