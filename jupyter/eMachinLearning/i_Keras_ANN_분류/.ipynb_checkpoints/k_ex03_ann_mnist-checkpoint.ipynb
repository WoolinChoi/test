# %%
##############################################
# Modeling
##############################################
from keras import layers, models
 
def ANN_seq_func(Nin, Nh, Nout):
    # Keras 모델 시작
    model = models.Sequential()
    
    # 입력 계층 노드 수 Nin 개, 은닉 계층의 노드 수 Nh 개, 활성함수는 relu
    model.add(layers.Dense(Nh, activation='relu', input_shape=(Nin, )))
    
    # 출력 노드 수 Nout 개, 활성함수는 softmax (다중 분류문제이므로)
    model.add(layers.Dense(Nout, activation='softmax'))
    
    """
    오차(비용) 함수는 categorical_crossentropy, <--(활성함수를 softmax를 사용함으로)
    최적화 함수는 adam 을 사용. SGD(확률적경사하강법) 써도 됨 
    Classification Performance metrics(분류 성능 척도) 는 'accuracy'
    """
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) 

    return model

##############################################
# Data
##############################################
from keras import datasets  # mnist
from keras.utils import np_utils  # to_categorical

def Data_func():
    """ 
    이미지 데이터 X ,  0~9까지 붙인 이름표를 Y   
    70,000개의 데이터 중 60,000개를 학습 데이터로,  
    10,000개를 테스트 데이터로 읽어옵니다. 
    """
    (X_train, y_train), (X_test, y_test) = datasets.mnist.load_data()
    
    """
    원-핫 인코딩을 위해 케라스의 np_utils 의 to_categorical() 함수를 사용
    0 ~ 9까지의 정수 값을 갖는 형태가 아닌 0 이나 1로 이뤄진 벡터로 수정 
    만약에 '3' 이라는 숫자이라면 [0, 0, 1, 0, 0, 0, 0, 0, 0]으로 변환 
    """
    Y_train = np_utils.to_categorical(y_train)
    Y_test = np_utils.to_categorical(y_test)

    L, W, H = X_train.shape 
    print(L, W, H)  # 6000 28 28 
    
    # 행 갯수는 상관없고, 열은 28*28(-> 784)로 reshape
    X_train = X_train.reshape(-1, W * H)
    X_test = X_test.reshape(-1, W * H)
     
    # 원래 데이터가 0~255 인데 0~1로  변환 (정규화)
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    return (X_train, Y_train), (X_test, Y_test)

##############################################
# Main   # 분류 ANN 학습 및 성능 분석 
##############################################
import matplotlib.pyplot as plt
# %matplotlib inline 

def main():
    Nin = 784
    Nh = 100
    number_of_class = 10
    Nout = number_of_class

    model = ANN_seq_func(Nin, Nh, Nout)
    (X_train, Y_train), (X_test, Y_test) = Data_func() 

    ##############################################
    # Training
    ##############################################
    history = model.fit(X_train, Y_train, epochs=15, batch_size=100, validation_split=0.2)
    
    # 평가
    performace_test = model.evaluate(X_test, Y_test, batch_size=100)
    print('Test Loss and Accuracy ->', performace_test)
    
    # 정확도 변화 추이 그래프
    history = history.history
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Verification'], loc=0)
    plt.show()

    # Cost/Loss  변화 추이  그래프
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Verification'], loc=0)
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# 60000 28 28
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/15
# 48000/48000 [==============================] - 2s 33us/step - loss: 0.3849 - accuracy: 0.8937 - val_loss: 0.2153 - val_accuracy: 0.9392
# Epoch 2/15
# 48000/48000 [==============================] - 2s 35us/step - loss: 0.1858 - accuracy: 0.9477 - val_loss: 0.1645 - val_accuracy: 0.9523
# Epoch 3/15
# 48000/48000 [==============================] - 2s 48us/step - loss: 0.1379 - accuracy: 0.9609 - val_loss: 0.1365 - val_accuracy: 0.9592
# Epoch 4/15
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.1105 - accuracy: 0.9675 - val_loss: 0.1167 - val_accuracy: 0.9660
# Epoch 5/15
# 48000/48000 [==============================] - 2s 39us/step - loss: 0.0905 - accuracy: 0.9746 - val_loss: 0.1094 - val_accuracy: 0.9677
# Epoch 6/15
# 48000/48000 [==============================] - 2s 40us/step - loss: 0.0774 - accuracy: 0.9774 - val_loss: 0.1026 - val_accuracy: 0.9693
# Epoch 7/15
# 48000/48000 [==============================] - 3s 52us/step - loss: 0.0640 - accuracy: 0.9820 - val_loss: 0.1001 - val_accuracy: 0.9708
# Epoch 8/15
# 48000/48000 [==============================] - 1s 31us/step - loss: 0.0554 - accuracy: 0.9845 - val_loss: 0.0987 - val_accuracy: 0.9712
# Epoch 9/15
# 48000/48000 [==============================] - 2s 32us/step - loss: 0.0481 - accuracy: 0.9869 - val_loss: 0.0933 - val_accuracy: 0.9718
# Epoch 10/15
# 48000/48000 [==============================] - 1s 30us/step - loss: 0.0403 - accuracy: 0.9892 - val_loss: 0.0924 - val_accuracy: 0.9725
# Epoch 11/15
# 48000/48000 [==============================] - 1s 30us/step - loss: 0.0346 - accuracy: 0.9912 - val_loss: 0.0923 - val_accuracy: 0.9725
# Epoch 12/15
# 48000/48000 [==============================] - 1s 30us/step - loss: 0.0309 - accuracy: 0.9920 - val_loss: 0.0956 - val_accuracy: 0.9714
# Epoch 13/15
# 48000/48000 [==============================] - 1s 29us/step - loss: 0.0267 - accuracy: 0.9934 - val_loss: 0.0990 - val_accuracy: 0.9711
# Epoch 14/15
# 48000/48000 [==============================] - 2s 34us/step - loss: 0.0226 - accuracy: 0.9945 - val_loss: 0.0947 - val_accuracy: 0.9723
# Epoch 15/15
# 48000/48000 [==============================] - 2s 40us/step - loss: 0.0187 - accuracy: 0.9958 - val_loss: 0.0941 - val_accuracy: 0.9732
# 10000/10000 [==============================] - 0s 30us/step
# Test Loss and Accuracy -> [0.08033103633497377, 0.9758999943733215]
