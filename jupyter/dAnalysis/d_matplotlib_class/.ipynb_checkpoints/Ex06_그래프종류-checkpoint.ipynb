# %%
import seaborn                   # 데이터
import matplotlib.pyplot as plt  # 그래프 라이브러리

tips = seaborn.load_dataset('tips') # 팁을 지불한 손님의 정보 데이터
tips.head()   # 지불금액 / 팁 / 성별 / 흡연 / 요일 / 시간대 / 인원수
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from matplotlib import font_manager, rc

plt.rcParams['axes.unicode_minus']=False  # 추가설정 : 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
rc('font', family='Malgun Gothic')

# %% [markdown]
# ## 1. 일변량 그래프 - 하나의 변수만 사용한 그래프 (*) 히스토그램
#
# - 막대그래프(범주변수: 카테고리, 성별)
#
# - 히스토그램(수치변수: 온도, 나이)
#
#   [예] 전체지불금액(total_bill)에 대한 그래프

# %%
plt.hist(tips['total_bill'])
plt.title('전체지불금액(total_bill)에 대한 그래프')
plt.xlabel('지불금액')
plt.ylabel('빈도수', rotation=0, ha='right')
# Out:
# Text(0, 0.5, '빈도수')

# %% [markdown]
# ##  2. 이변량 그래프 - 변수 2개를 이용한 그래프 ( 산점도 그래프 )
#     [예] 지불금액에 따른 팁 금액을 나타내는 그래프

# %%
plt.scatter(tips['total_bill'], tips['tip'])
plt.title('지불금액에 따른 팁 금액을 나타내는 그래프')
plt.xlabel('지불금액')
plt.ylabel('팁', rotation=0, ha='right')
# Out:
# Text(0, 0.5, '팁')

# %% [markdown]
# ## 3. 이산형 변수와 연속형 변수 - 박스플롯
#
# - 이산형 - 성별이나 국적처럼 명확하게 구분되는 값
#
# - 연속형 - 수치로 이루어진 값
#
# [예] 성별에 따른 팁을 나타내는 그래프

# %%
female = tips[tips['sex'] == 'Female']['tip']
male = tips[tips['sex'] == 'Male']['tip']

plt.boxplot([female, male], labels=['여자', '남자'])
plt.title('성별에 따른 팁을 나타내는 그래프')
plt.xlabel('성별')
plt.ylabel('팁', rotation=0, ha='right')
# Out:
# Text(0, 0.5, '팁')

# %% [markdown]
# ##  4. 다변량 그래프 - 3개 이상의 변수로 그래프 - 산점도 그래프
#
#       [예] 식사지불과 팁의 정도를 성별에 따라 그래프를 그린다면?
#
#       * 성별의 문자열값을 0과 1로 변경하여 다른 색상으로 그리고자 한다

# %%
# (1) 성별을 0과 1로 변환하는 함수 선언
import numpy as np

tips['sex_color'] = np.where(tips['sex']=='Female', 0, 1)
tips.head()

# %%
# (1) 성별을 0과 1로 변환하는 함수 선언
def change_sex(sex):
    if sex == 'Male': return 0
    else: return 1

# (2) 변경한 성별값의 변수(컬럼 sex_color) 추가
tips2 = tips
tips2['sex_color'] = tips['sex'].apply(change_sex)
tips2.tail()

# (3) 그래프 : x와 y 축, c=점의 색상, alpha=점의 투명도, s=점의 크기
# 테이블당의 인원수를 점의 크기로 표현한다면 s=tips['size']*10 추가
plt.scatter(tips['total_bill'], tips['tip'], c=tips['sex_color'], alpha=0.5, s=tips['size']*10)

# %%
male = tips[tips['sex'] == 'Male'][['total_bill', 'tip']]
female = tips[tips['sex'] == 'Female'][['total_bill', 'tip']]

plt.scatter(male['total_bill'], male['tip'], label='남자')
plt.scatter(female['total_bill'], female['tip'], label='여자')
plt.legend(loc=2)
plt.title('식사지불과 팁의 정도를 성별에 따른 그래프')
# Out:
# Text(0.5, 1.0, '식사지불과 팁의 정도를 성별에 따른 그래프')

# %% [markdown]
# [ 참고 ]  plt.scatter와 plt.plot 정리
