# %% [markdown]
# # 미국 주와 주별 인구 데이타 예제
#      - 2010년도 인구 밀도 기준으로 미국 주와 지역 순위를 출력
#
# 1. 데이타를 로딩 후 데이타 정보 확인
#
#
# 2. 데이타 연결
#         1- 인구 데이타와 주이름 약어 데이타를 연결
#             ( 각 주의 전체 이름과 인구를 볼 수 있도록 )
#
#         2- 각 주의 인구 데이타와 면적 데이타를 연결
#             ( 각 주의 면적당 인구를 계산하여 인구 밀도를 구하기 )
#
# 3. 데이타 정제(데이타 전처리)
#      * 누락값 처리
#         1. 삭제한다
#         2. 대체한다
#
#     실제로 2000년 이전의 PR(푸에르토리토)의 인구 데이타가 없는 것이다.
#     여기서는 2010년 데이타를 구할 것이기에 삭제해도 되지만 대체하는 방식을 연습한다
#     또한 전체 미국을 뜻하는 USA에 state와 abbreviation이 없다.
#
#
# 4. 2010년 인구밀도 계산하고 표현
#         인구밀도 = 인구 / 면적
#
#
#
#     [도서] 파이썬 데이타 사이언스 핸드북 - 위키북스/오렐리

# %% [markdown]
# ## 1. 데이타를 로딩 후 데이타 정보 확인

# %%
# 1. 데이타를 로딩 후 데이타 정보 확인
import pandas as pd

pop = pd.read_csv('./data/state-population.csv')    # 주별 인구
areas = pd.read_csv('./data/state-areas.csv')       # 주의 면적
abbrevs = pd.read_csv('./data/state-abbrevs.csv')   # 주이름 약자

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
pop.shape
# Out:
# (2544, 4)

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
areas.shape
# Out:
# (52, 2)

# %%
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
abbrevs.shape
# Out:
# (51, 2)

# %% [markdown]
# ## 2. 데이타 연결
# - 인구 데이타(pop)와 주이름 약어 데이타(abbrevs)를 연결(각 주의 전체 이름과 인구를 볼 수 있도록)
# - 각 주의 인구 데이타(pop)와 면적 데이타(areas)를 연결(각 주의 면적당 인구를 계산하여 인구 밀도를 구하기)

# %%
dataset1 = abbrevs.merge(pop, left_on='abbreviation', right_on='state/region', how='outer')
dataset1.head()
dataset2 = dataset1[['state','abbreviation','ages','year','population']]
dataset2.head()
# Out:
#      state abbreviation     ages  year  population
# 0  Alabama           AL  under18  2012   1117489.0
# 1  Alabama           AL    total  2012   4817528.0
# 2  Alabama           AL  under18  2010   1130966.0
# 3  Alabama           AL    total  2010   4785570.0
# 4  Alabama           AL  under18  2011   1125763.0

# %%
dataset3 = dataset2.merge(areas, left_on='state', right_on='state', how='outer')
dataset3.head()
# Out:
#      state abbreviation     ages    year  population  area (sq. mi)
# 0  Alabama           AL  under18  2012.0   1117489.0        52423.0
# 1  Alabama           AL    total  2012.0   4817528.0        52423.0
# 2  Alabama           AL  under18  2010.0   1130966.0        52423.0
# 3  Alabama           AL    total  2010.0   4785570.0        52423.0
# 4  Alabama           AL  under18  2011.0   1125763.0        52423.0

# %% [markdown]
# ##  3. 데이타 정제 -    누락값 처리
#
#         (1) 삭제한다
#         (2) 대체한다
#
#     실제로 2000년 이전의 PR(푸에르토리토)의 인구 데이타가 없는 것이다.
#     여기서는 2010년 데이타를 구할 것이기에 삭제해도 되지만 대체하는 방식을 연습한다
#     또한 전체 미국을 뜻하는 USA에 state와 abbreviation이 없다.

# %% [markdown]
# ### (1) null 값 확인

# %%
# %matplotlib inline
import missingno as msno

msno.matrix(dataset3)

# %% [markdown]
# ### (2) 우선 state 컬럼의 null 처리

# %%
import numpy as np

dataset3['state'] = dataset3['state'].replace(np.nan, 'United States')
dataset3.head()
# Out:
#      state abbreviation     ages    year  population  area (sq. mi)
# 0  Alabama           AL  under18  2012.0   1117489.0        52423.0
# 1  Alabama           AL    total  2012.0   4817528.0        52423.0
# 2  Alabama           AL  under18  2010.0   1130966.0        52423.0
# 3  Alabama           AL    total  2010.0   4785570.0        52423.0
# 4  Alabama           AL  under18  2011.0   1125763.0        52423.0

# %% [markdown]
# ## 4. 각 주의 인구를 연결한 데이타셋에 주의 면적 데이타 셋을 연결하기 (merge이용)
# ### (1) pop과 abbreviation의 연결한 데이타셋과 areas(면적) 데이타셋을 연결

# %%
dataset3.head()
# Out:
#      state abbreviation     ages    year  population  area (sq. mi)
# 0  Alabama           AL  under18  2012.0   1117489.0        52423.0
# 1  Alabama           AL    total  2012.0   4817528.0        52423.0
# 2  Alabama           AL  under18  2010.0   1130966.0        52423.0
# 3  Alabama           AL    total  2010.0   4785570.0        52423.0
# 4  Alabama           AL  under18  2011.0   1125763.0        52423.0

# %% [markdown]
# ### (2) 널 값 여부 확인

# %%
import missingno as msno
# %matplotlib inline

msno.matrix(dataset3)

# %% [markdown]
# ### (3) 널값 확인 : 면적값이 널인 주를 찾으면

# %%
dataset3[dataset3['area (sq. mi)'].isnull()].head()
# Out:
#               state abbreviation     ages    year  population  area (sq. mi)
# 2448  United States          NaN  under18  1990.0         NaN            NaN
# 2449  United States          NaN    total  1990.0         NaN            NaN
# 2450  United States          NaN    total  1991.0         NaN            NaN
# 2451  United States          NaN  under18  1991.0         NaN            NaN
# 2452  United States          NaN    total  1993.0         NaN            NaN

# %% [markdown]
# ### (4) 널값 처리 : 데이타 삭제하기
# - 미국 전역에 대한 데이타는 인구 밀도와 관련이 없기에 삭제

# %%
df = dataset3.dropna()
df
# Out:
#         state abbreviation     ages    year  population  area (sq. mi)
# 0     Alabama           AL  under18  2012.0   1117489.0        52423.0
# 1     Alabama           AL    total  2012.0   4817528.0        52423.0
# 2     Alabama           AL  under18  2010.0   1130966.0        52423.0
# 3     Alabama           AL    total  2010.0   4785570.0        52423.0
# 4     Alabama           AL  under18  2011.0   1125763.0        52423.0
# 5     Alabama           AL    total  2011.0   4801627.0        52423.0
# 6     Alabama           AL    total  2009.0   4757938.0        52423.0
# 7     Alabama           AL  under18  2009.0   1134192.0        52423.0
# 8     Alabama           AL  under18  2013.0   1111481.0        52423.0
# 9     Alabama           AL    total  2013.0   4833722.0        52423.0
# 10    Alabama           AL    total  2007.0   4672840.0        52423.0
# 11    Alabama           AL  under18  2007.0   1132296.0        52423.0
# 12    Alabama           AL    total  2008.0   4718206.0        52423.0
# 13    Alabama           AL  under18  2008.0   1134927.0        52423.0
# 14    Alabama           AL    total  2005.0   4569805.0        52423.0
# 15    Alabama           AL  under18  2005.0   1117229.0        52423.0
# 16    Alabama           AL    total  2006.0   4628981.0        52423.0
# 17    Alabama           AL  under18  2006.0   1126798.0        52423.0
# 18    Alabama           AL    total  2004.0   4530729.0        52423.0
# 19    Alabama           AL  under18  2004.0   1113662.0        52423.0
# 20    Alabama           AL    total  2003.0   4503491.0        52423.0
# 21    Alabama           AL  under18  2003.0   1113083.0        52423.0
# 22    Alabama           AL    total  2001.0   4467634.0        52423.0
# 23    Alabama           AL  under18  2001.0   1120409.0        52423.0
# 24    Alabama           AL    total  2002.0   4480089.0        52423.0
# 25    Alabama           AL  under18  2002.0   1116590.0        52423.0
# 26    Alabama           AL  under18  1999.0   1121287.0        52423.0
# 27    Alabama           AL    total  1999.0   4430141.0        52423.0
# 28    Alabama           AL    total  2000.0   4452173.0        52423.0
# 29    Alabama           AL  under18  2000.0   1122273.0        52423.0
# ...       ...          ...      ...     ...         ...            ...
# 2418  Wyoming           WY    total  2003.0    503453.0        97818.0
# 2419  Wyoming           WY  under18  2003.0    124182.0        97818.0
# 2420  Wyoming           WY    total  2004.0    509106.0        97818.0
# 2421  Wyoming           WY  under18  2004.0    123974.0        97818.0
# 2422  Wyoming           WY    total  2002.0    500017.0        97818.0
# 2423  Wyoming           WY  under18  2002.0    125495.0        97818.0
# 2424  Wyoming           WY    total  2001.0    494657.0        97818.0
# 2425  Wyoming           WY  under18  2001.0    126212.0        97818.0
# 2426  Wyoming           WY    total  2000.0    494300.0        97818.0
# 2427  Wyoming           WY  under18  2000.0    128774.0        97818.0
# 2428  Wyoming           WY    total  1999.0    491780.0        97818.0
# 2429  Wyoming           WY  under18  1999.0    130793.0        97818.0
# 2430  Wyoming           WY    total  1997.0    489452.0        97818.0
# 2431  Wyoming           WY  under18  1997.0    134328.0        97818.0
# 2432  Wyoming           WY  under18  1998.0    132602.0        97818.0
# 2433  Wyoming           WY    total  1998.0    490787.0        97818.0
# 2434  Wyoming           WY  under18  1996.0    135698.0        97818.0
# 2435  Wyoming           WY    total  1996.0    488167.0        97818.0
# 2436  Wyoming           WY    total  1995.0    485160.0        97818.0
# 2437  Wyoming           WY  under18  1995.0    136785.0        97818.0
# 2438  Wyoming           WY  under18  1994.0    137733.0        97818.0
# 2439  Wyoming           WY    total  1994.0    480283.0        97818.0
# 2440  Wyoming           WY  under18  1992.0    137308.0        97818.0
# 2441  Wyoming           WY    total  1992.0    466251.0        97818.0
# 2442  Wyoming           WY    total  1993.0    473081.0        97818.0
# 2443  Wyoming           WY  under18  1993.0    137458.0        97818.0
# 2444  Wyoming           WY    total  1991.0    459260.0        97818.0
# 2445  Wyoming           WY  under18  1991.0    136720.0        97818.0
# 2446  Wyoming           WY  under18  1990.0    136078.0        97818.0
# 2447  Wyoming           WY    total  1990.0    453690.0        97818.0
#
# [2448 rows x 6 columns]

# %% [markdown]
# ### (1) [결과확인] 면적이 null 값이 있는지 없는지 확인

# %%
df.isnull().sum()
# Out:
# state            0
# abbreviation     0
# ages             0
# year             0
# population       0
# area (sq. mi)    0
# dtype: int64

# %% [markdown]
# ## 2010년 인구밀도 계산하고 표현
# - 인구밀도 = 인구 / 면적
# - 필요한 데이타는 2010년 전체 인구에 대한 데이타집합이다.

# %% [markdown]
# ### 필요한 데이타집합 추출

# %%
data = df[df['year']==2010]
data = data[df['ages']=='total']
data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                      state abbreviation   ages    year  population  \
# 3                  Alabama           AL  total  2010.0   4785570.0
# 91                  Alaska           AK  total  2010.0    713868.0
# 101                Arizona           AZ  total  2010.0   6408790.0
# 189               Arkansas           AR  total  2010.0   2922280.0
# 197             California           CA  total  2010.0  37333601.0
# 283               Colorado           CO  total  2010.0   5048196.0
# 293            Connecticut           CT  total  2010.0   3579210.0
# 379               Delaware           DE  total  2010.0    899711.0
# 389   District of Columbia           DC  total  2010.0    605125.0
# 475                Florida           FL  total  2010.0  18846054.0
# 485                Georgia           GA  total  2010.0   9713248.0
# 570                 Hawaii           HI  total  2010.0   1363731.0
# 581                  Idaho           ID  total  2010.0   1570718.0
# 666               Illinois           IL  total  2010.0  12839695.0
# 677                Indiana           IN  total  2010.0   6489965.0
# 762                   Iowa           IA  total  2010.0   3050314.0
# 773                 Kansas           KS  total  2010.0   2858910.0
# 858               Kentucky           KY  total  2010.0   4347698.0
# 869              Louisiana           LA  total  2010.0   4545392.0
# 954                  Maine           ME  total  2010.0   1327366.0
# 965                Montana           MT  total  2010.0    990527.0
# 1050              Nebraska           NE  total  2010.0   1829838.0
# 1061                Nevada           NV  total  2010.0   2703230.0
# 1146         New Hampshire           NH  total  2010.0   1316614.0
# 1157            New Jersey           NJ  total  2010.0   8802707.0
# 1242            New Mexico           NM  total  2010.0   2064982.0
# 1253              New York           NY  total  2010.0  19398228.0
# 1338        North Carolina           NC  total  2010.0   9559533.0
# 1349          North Dakota           ND  total  2010.0    674344.0
# 1434                  Ohio           OH  total  2010.0  11545435.0
# 1445              Oklahoma           OK  total  2010.0   3759263.0
# 1530                Oregon           OR  total  2010.0   3837208.0
# 1541              Maryland           MD  total  2010.0   5787193.0
# 1626         Massachusetts           MA  total  2010.0   6563263.0
# 1637              Michigan           MI  total  2010.0   9876149.0
# 1722             Minnesota           MN  total  2010.0   5310337.0
# 1733           Mississippi           MS  total  2010.0   2970047.0
# 1818              Missouri           MO  total  2010.0   5996063.0
# 1829          Pennsylvania           PA  total  2010.0  12710472.0
# 1914          Rhode Island           RI  total  2010.0   1052669.0
# 1925        South Carolina           SC  total  2010.0   4636361.0
# 2010          South Dakota           SD  total  2010.0    816211.0
# 2021             Tennessee           TN  total  2010.0   6356683.0
# 2106                 Texas           TX  total  2010.0  25245178.0
# 2117                  Utah           UT  total  2010.0   2774424.0
# 2202               Vermont           VT  total  2010.0    625793.0
# 2213              Virginia           VA  total  2010.0   8024417.0
# 2298            Washington           WA  total  2010.0   6742256.0
# 2309         West Virginia           WV  total  2010.0   1854146.0
# 2394             Wisconsin           WI  total  2010.0   5689060.0
# 2405               Wyoming           WY  total  2010.0    564222.0
#
#       area (sq. mi)
# 3           52423.0
# 91         656425.0
# 101        114006.0
# 189         53182.0
# 197        163707.0
# 283        104100.0
# 293          5544.0
# 379          1954.0
# 389            68.0
# 475         65758.0
# 485         59441.0
# 570         10932.0
# 581         83574.0
# 666         57918.0
# 677         36420.0
# 762         56276.0
# 773         82282.0
# 858         40411.0
# 869         51843.0
# 954         35387.0
# 965        147046.0
# 1050        77358.0
# 1061       110567.0
# 1146         9351.0
# 1157         8722.0
# 1242       121593.0
# 1253        54475.0
# 1338        53821.0
# 1349        70704.0
# 1434        44828.0
# 1445        69903.0
# 1530        98386.0
# 1541        12407.0
# 1626        10555.0
# 1637        96810.0
# 1722        86943.0
# 1733        48434.0
# 1818        69709.0
# 1829        46058.0
# 1914         1545.0
# 1925        32007.0
# 2010        77121.0
# 2021        42146.0
# 2106       268601.0
# 2117        84904.0
# 2202         9615.0
# 2213        42769.0
# 2298        71303.0
# 2309        24231.0
# 2394        65503.0
# 2405        97818.0

# %% [markdown]
# ### 주(state)를 기준으로 데이타 인덱스를 정하고 인구밀도 계산

# %%
data.set_index('state', inplace=True)

density = data['population']/data['area (sq. mi)']
density

density.sort_values(ascending=False, inplace=True)
data['density'] = density
density
# Out:
# state
# District of Columbia    8898.897059
# New Jersey              1009.253268
# Rhode Island             681.339159
# Connecticut              645.600649
# Massachusetts            621.815538
# Maryland                 466.445797
# Delaware                 460.445752
# New York                 356.094135
# Florida                  286.597129
# Pennsylvania             275.966651
# Ohio                     257.549634
# California               228.051342
# Illinois                 221.687472
# Virginia                 187.622273
# Indiana                  178.197831
# North Carolina           177.617157
# Georgia                  163.409902
# Tennessee                150.825298
# South Carolina           144.854594
# New Hampshire            140.799273
# Hawaii                   124.746707
# Kentucky                 107.586994
# Michigan                 102.015794
# Washington                94.557817
# Texas                     93.987655
# Alabama                   91.287603
# Louisiana                 87.676099
# Wisconsin                 86.851900
# Missouri                  86.015622
# West Virginia             76.519582
# Vermont                   65.085075
# Mississippi               61.321530
# Minnesota                 61.078373
# Arizona                   56.214497
# Arkansas                  54.948667
# Iowa                      54.202751
# Oklahoma                  53.778278
# Colorado                  48.493718
# Oregon                    39.001565
# Maine                     37.509990
# Kansas                    34.745266
# Utah                      32.677188
# Nevada                    24.448796
# Nebraska                  23.654153
# Idaho                     18.794338
# New Mexico                16.982737
# South Dakota              10.583512
# North Dakota               9.537565
# Montana                    6.736171
# Wyoming                    5.768079
# Alaska                     1.087509
# dtype: float64

# %% [markdown]
# ### [결과]
#
#         state
#         District of Columbia    8898.897059
#         New Jersey              1009.253268
#         Rhode Island             681.339159
#         Connecticut              645.600649
#         Massachusetts            621.815538
#         Maryland                 466.445797
#         Delaware                 460.445752
#         New York                 356.094135
#         Florida                  286.597129
#         Pennsylvania             275.966651
#         Ohio                     257.549634
#         California               228.051342
#         Illinois                 221.687472
#         Virginia                 187.622273
#         Indiana                  178.197831
#         North Carolina           177.617157
#         Georgia                  163.409902
#         Tennessee                150.825298
#         South Carolina           144.854594
#         New Hampshire            140.799273
#         Hawaii                   124.746707
#         Kentucky                 107.586994
#         Michigan                 102.015794
#         Washington                94.557817
#         Texas                     93.987655
#         Alabama                   91.287603
#         Louisiana                 87.676099
#         Wisconsin                 86.851900
#         Missouri                  86.015622
#         West Virginia             76.519582
#         Vermont                   65.085075
#         Mississippi               61.321530
#         Minnesota                 61.078373
#         Arizona                   56.214497
#         Arkansas                  54.948667
#         Iowa                      54.202751
#         Oklahoma                  53.778278
#         Colorado                  48.493718
#         Oregon                    39.001565
#         Maine                     37.509990
#         Kansas                    34.745266
#         Utah                      32.677188
#         Nevada                    24.448796
#         Nebraska                  23.654153
#         Idaho                     18.794338
#         New Mexico                16.982737
#         South Dakota              10.583512
#         North Dakota               9.537565
#         Montana                    6.736171
#         Wyoming                    5.768079
#         Alaska                     1.087509
#
#
# ---

# %% [markdown]
#   [분석결과]
#
#   인구 밀도가 가장 높은 주는 District of Columbia(DC) 워싱톤DC 이고
#   그 다음은 Puerto Rico 이다.
#
#   인구 밀도가 가장 작은 Alaska는 1제곱마일당 평균 주민수가 1만명정도이다.

# %% [markdown]
# ### 시각화작업

# %%
import matplotlib.pyplot as plt
import seaborn as sns

axes = plt.figure(figsize=(15,6)) # this creates a figure 8 inch wide, 4 inch high
axes = sns.barplot(x=data['abbreviation'], y=data['density'])
axes.set_title('Population Density by State of the U.S.(2010)');
